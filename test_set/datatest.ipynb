# %%
import pandas as pd

# %%
df = pd.read_csv('combined_testsets.csv')
df.head(10)
# Out:
#                                             Question  \
# 0     Luật Doanh nghiệp quy định về những vấn đề gì?
# 1      Đối tượng nào được áp dụng Luật Doanh nghiệp?
# 2              Cổ đông là gì theo Luật Doanh nghiệp?
# 3                       Thế nào là cổ đông sáng lập?
# 4                                     Góp vốn là gì?
# 5         Doanh nghiệp phải lưu giữ các tài liệu gì?
# 6  Người đại diện theo pháp luật của doanh nghiệp...
# 7  Quyền và nghĩa vụ của doanh nghiệp cung ứng sả...
# 8  Điều kiện để doanh nghiệp được cấp Giấy chứng ...
# 9  Thời hạn thông báo công khai thông tin về doan...
#
#                                               Answer  \
# 0  Luật Doanh nghiệp quy định về việc thành lập, ...
# 1  Luật Doanh nghiệp áp dụng cho doanh nghiệp, cơ...
# 2  Cổ đông là cá nhân, tổ chức sở hữu ít nhất một...
# 3  Cổ đông sáng lập là cổ đông sở hữu ít nhất một...
# 4  Góp vốn là việc góp tài sản để tạo thành vốn đ...
# 5  Doanh nghiệp phải lưu giữ các tài liệu như Điề...
# 6  Người đại diện theo pháp luật của doanh nghiệp...
# 7  Doanh nghiệp cung ứng sản phẩm, dịch vụ công í...
# 8  Doanh nghiệp được cấp Giấy chứng nhận đăng ký ...
# 9  Thời hạn thông báo công khai thông tin về doan...
#
#                                            Reference Trust_lv Type_question
# 0                         Điều 1. Phạm vi điều chỉnh     High       General
# 1                          Điều 2. Đối tượng áp dụng     High       General
# 2                          Điều 4. Giải thích từ ngữ     High    Definition
# 3                          Điều 4. Giải thích từ ngữ     High    Definition
# 4                          Điều 4. Giải thích từ ngữ     High    Definition
# 5  Điều 11. Chế độ lưu giữ tài liệu của doanh nghiệp     High    Regulation
# 6  Điều 12. Người đại diện theo pháp luật của doa...     High    Definition
# 7  Điều 9. Quyền và nghĩa vụ của doanh nghiệp cun...     High    Regulation
# 8  Điều 27. Cấp Giấy chứng nhận đăng ký doanh nghiệp     High    Regulation
# 9     Điều 32. Công bố nội dung đăng ký doanh nghiệp     High    Regulation

# %%
df.tail(10)
# Out:
#                                               Question  \
# 149  Doanh nghiệp có quyền lựa chọn hình thức trả l...
# 150  Công ty TNHH hai thành viên trở lên có phải lậ...
# 151  Doanh nghiệp có quyền góp vốn, mua cổ phần tro...
# 152  Người đại diện theo pháp luật của doanh nghiệp...
# 153  Công ty TNHH một thành viên có thể phát hành t...
# 154     Doanh nghiệp có quyền tự chủ kinh doanh không?
# 155       Thành viên hợp danh có thể là tổ chức không?
# 156  Công ty TNHH hai thành viên trở lên có thể phá...
# 157  Cổ phần phổ thông có thể chuyển nhượng tự do k...
# 158  Công ty TNHH một thành viên có thể có nhiều hơ...
#
#                                                 Answer  \
# 149  Doanh nghiệp có quyền lựa chọn hình thức trả l...
# 150  Công ty TNHH hai thành viên trở lên phải lập B...
# 151  Doanh nghiệp có quyền góp vốn, mua cổ phần, mu...
# 152  Người đại diện theo pháp luật của doanh nghiệp...
# 153  Công ty TNHH một thành viên có quyền phát hành...
# 154  Doanh nghiệp có quyền tự chủ kinh doanh và lựa...
# 155  Thành viên hợp danh phải là cá nhân, không thể...
# 156  Công ty TNHH hai thành viên trở lên không được...
# 157  Cổ phần phổ thông có thể được tự do chuyển như...
# 158  Công ty TNHH một thành viên chỉ có một chủ sở ...
#
#                                              Reference Trust_lv Type_question
# 149     Điều 90: Hình thức trả lương, Bộ luật Lao động     High    Regulation
# 150                             Điều 54: Ban kiểm soát     High    Regulation
# 151  Điều 18: Quyền góp vốn, mua cổ phần, mua phần ...     High    Regulation
# 152  Điều 13: Trách nhiệm của người đại diện theo p...     High    Regulation
# 153  Điều 74: Công ty trách nhiệm hữu hạn một thành...     High    Regulation
# 154                     Điều 7: Quyền của doanh nghiệp     High    Regulation
# 155                         Điều 172: Công ty hợp danh     High    Regulation
# 156  Điều 46: Công ty trách nhiệm hữu hạn hai thành...     High    Regulation
# 157                    Điều 127: Chuyển nhượng cổ phần     High    Regulation
# 158  Điều 74: Công ty trách nhiệm hữu hạn một thành...     High    Regulation

# %%
df.describe()
# Out:
#                                                  Question  \
# count                                                 159
# unique                                                131
# top     Người đại diện theo pháp luật của doanh nghiệp...
# freq                                                    3
#
#                                                    Answer  \
# count                                                 159
# unique                                                131
# top     Công ty TNHH một thành viên chỉ có một chủ sở ...
# freq                                                    3
#
#                                          Reference Trust_lv Type_question
# count                                          159      159           159
# unique                                          70        1             3
# top     Điều 7: Quyền và nghĩa vụ của doanh nghiệp     High    Regulation
# freq                                            13      159           150

# %%
trust_lv_counts = df['Trust_lv'].value_counts()
print("Mức độ tin cậy:")
print(trust_lv_counts)
# Out:
# Mức độ tin cậy:
# Trust_lv
# High    159
# Name: count, dtype: int64

# %%
type_q_counts = df['Type_question'].value_counts()
print("Các loai câu hỏi:")
print(type_q_counts)
# Out:
# Các loai câu hỏi:
# Type_question
# Regulation    150
# Definition      7
# General         2
# Name: count, dtype: int64

# %%
import pandas as pd
import json
import re
import codecs
with open('/Users/nhotin/Documents/GitHub/LegalBizAI_project/data/finetune/raw/llm_finetune_db.finetune_pairs_v2.json', 'r', encoding='utf-8') as file:
    data = json.load(file)

# %%
for i, entry in enumerate(data):
    entry['id'] = int(i)
    # Xóa cột _id.$oid
    if '_id' in entry:
        del entry['_id']

# %%
# Convert the JSON data to a Pandas DataFrame
df = pd.json_normalize(data)

# %%
df.head()
# Out:
#                                             question  \
# 0  Chi nhánh ngân hàng nước ngoài được quyết định...
# 1  Đối với chi nhánh ngân hàng nước ngoài, việc x...
# 2  Hồ sơ xuất toán nợ ra khỏi ngoại bảng đối với ...
# 3  Trách nhiệm của cơ quan hải quan trong kiểm tr...
# 4  Định mức thực tế sản xuất hàng hóa gia công...
#
#                                               answer  \
# 0  Căn cứ theo khoản 1 Điều 17 Thông tư 11/2021/T...
# 1  Căn cứ theo khoản 5 Điều 17 Thông tư 11/2021/T...
# 2  Căn cứ theo khoản 6 Điều 17 Thông tư 11/2021/T...
# 3  Theo quy định tại Điều 59 Luật Hải quan 2014 q...
# 4  Tại khoản 35 Điều 1 Thông tư 39/2018/TT-BTC sử...
#
#                                           references  \
# 0  [https://thuvienphapluat.vn/van-ban/Tien-te-Ng...
# 1  [https://thuvienphapluat.vn/van-ban/Tien-te-Ng...
# 2  [https://thuvienphapluat.vn/van-ban/Tien-te-Ng...
# 3  [https://thuvienphapluat.vn/van-ban/Thuong-mai...
# 4  [https://thuvienphapluat.vn/van-ban/Xuat-nhap-...
#
#                                         request_link  id
# 0  https://thuvienphapluat.vn/phap-luat/doi-voi-c...   0
# 1  https://thuvienphapluat.vn/phap-luat/doi-voi-c...   1
# 2  https://thuvienphapluat.vn/phap-luat/doi-voi-c...   2
# 3  https://thuvienphapluat.vn/phap-luat/ho-tro-ph...   3
# 4  https://thuvienphapluat.vn/phap-luat/ho-tro-ph...   4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114510 entries, 0 to 114509
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   question      114510 non-null  object
#  1   answer        114510 non-null  object
#  2   references    114510 non-null  object
#  3   request_link  114510 non-null  object
#  4   id            114510 non-null  int64
# dtypes: int64(1), object(4)
# memory usage: 4.4+ MB

# %%
df.drop_duplicates(subset=['question'], inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 110228 entries, 0 to 114508
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   question      110228 non-null  object
#  1   answer        110228 non-null  object
#  2   references    110228 non-null  object
#  3   request_link  110228 non-null  object
#  4   id            110228 non-null  int64
# dtypes: int64(1), object(4)
# memory usage: 5.0+ MB

# %%
# Chuyển đổi kiểu dữ liệu cột
for col in df.columns:
    if col != 'id':
        df[col] = df[col].astype(str)

# %%
# Loại bỏ các bản ghi có giá trị null hoặc mảng rỗng ("[]") trong các cột quan trọng
df.replace(to_replace=["[]", "", None], value=pd.NA, inplace=True)
df.dropna(subset=['question', 'answer', 'references', 'request_link'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 109846 entries, 0 to 114508
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   question      109846 non-null  object
#  1   answer        109846 non-null  object
#  2   references    109846 non-null  object
#  3   request_link  109846 non-null  object
#  4   id            109846 non-null  int64
# dtypes: int64(1), object(4)
# memory usage: 5.0+ MB

# %%
df.head()
# Out:
#                                             question  \
# 0  Chi nhánh ngân hàng nước ngoài được quyết định...
# 1  Đối với chi nhánh ngân hàng nước ngoài, việc x...
# 2  Hồ sơ xuất toán nợ ra khỏi ngoại bảng đối với ...
# 3  Trách nhiệm của cơ quan hải quan trong kiểm tr...
# 4  Định mức thực tế sản xuất hàng hóa gia công...
#
#                                               answer  \
# 0  Căn cứ theo khoản 1 Điều 17 Thông tư 11/2021/T...
# 1  Căn cứ theo khoản 5 Điều 17 Thông tư 11/2021/T...
# 2  Căn cứ theo khoản 6 Điều 17 Thông tư 11/2021/T...
# 3  Theo quy định tại Điều 59 Luật Hải quan 2014 q...
# 4  Tại khoản 35 Điều 1 Thông tư 39/2018/TT-BTC sử...
#
#                                           references  \
# 0  ['https://thuvienphapluat.vn/van-ban/Tien-te-N...
# 1  ['https://thuvienphapluat.vn/van-ban/Tien-te-N...
# 2  ['https://thuvienphapluat.vn/van-ban/Tien-te-N...
# 3  ['https://thuvienphapluat.vn/van-ban/Thuong-ma...
# 4  ['https://thuvienphapluat.vn/van-ban/Xuat-nhap...
#
#                                         request_link  id
# 0  https://thuvienphapluat.vn/phap-luat/doi-voi-c...   0
# 1  https://thuvienphapluat.vn/phap-luat/doi-voi-c...   1
# 2  https://thuvienphapluat.vn/phap-luat/doi-voi-c...   2
# 3  https://thuvienphapluat.vn/phap-luat/ho-tro-ph...   3
# 4  https://thuvienphapluat.vn/phap-luat/ho-tro-ph...   4

# %%
link_counts = df['request_link'].value_counts()
frequency_df = link_counts.value_counts().rename_axis('count').reset_index(name='frequency')
print(frequency_df)
# Out:
#    count  frequency
# 0      3      30533
# 1      2       2677
# 2      4       2605
# 3      1        621
# 4      5        280
# 5      6         58
# 6      7          9
# 7      8          4
# 8      9          1

# %%
unique_counts = frequency_df['count'].unique()
count = 9
if count in unique_counts:
    print(f"\nCác liên kết xuất hiện {count} lần:")
    links = link_counts[link_counts == count].index.tolist()
    for link in links:
        print(link)
else:
        print(f"Không có liên kết nào xuất hiện {count} lần.")
# Out:
# Các liên kết xuất hiện 9 lần:
# https://thuvienphapluat.vn/phap-luat/ho-tro-phap-luat/thong-tu-182022ttbldtbxh-bai-bo-11-thong-tu-ve-tien-luong-bao-hiem-xa-hoi-tu-ngay-15112022-41349.html

# %%
# Kiểm tra số lượng câu hỏi kết thúc bằng dấu chấm hỏi
num_with_question_mark = df['question'].str.endswith('?').sum()
print(f"Số lượng câu kết thúc bằng dấu chấm hỏi: {num_with_question_mark}")
# Out:
# Số lượng câu kết thúc bằng dấu chấm hỏi: 107379

# %%
# Lấy ra các câu không kết thúc bằng dấu chấm hỏi
dfnoq = df[~df['question'].str.endswith('?')]
dfnoq.head()
# Out:
#                                              question  \
# 6   Quy định pháp luật về các từ viết tắt trong bả...
# 8   Các trường hợp không được hưởng bảo hiểm y tế ...
# 29                     Thẩm quyền công bố mở bến cảng
# 30                        Thủ tục công bố mở bến cảng
# 42                        Nguyên tắc đăng ký tàu biển
#
#                                                answer  \
# 6   Căn cứ khoản 1 Điều 2 Quyết định 595/QĐ-BHXH n...
# 8   Căn cứ Điều 23 Luật Bảo hiểm y tế 2008 quy địn...
# 29  Theo Điều 12 Nghị định 58/2017/NĐ-CP quy định ...
# 30  Theo Điều 14 Nghị định 58/2017/NĐ-CP quy định ...
# 42  Điều 18 Bộ luật Hàng hải Việt Nam 2015 quy địn...
#
#                                            references  \
# 6   ['https://thuvienphapluat.vn/van-ban/Bao-hiem/...
# 8   ['https://thuvienphapluat.vn/van-ban/Bao-hiem/...
# 29  ['https://thuvienphapluat.vn/van-ban/Giao-thon...
# 30  ['https://thuvienphapluat.vn/van-ban/Giao-thon...
# 42  ['https://thuvienphapluat.vn/van-ban/Giao-thon...
#
#                                          request_link  id
# 6   https://thuvienphapluat.vn/phap-luat/trong-tho...   6
# 8   https://thuvienphapluat.vn/phap-luat/trong-tho...   8
# 29  https://thuvienphapluat.vn/phap-luat/muon-dua-...  29
# 30  https://thuvienphapluat.vn/phap-luat/muon-dua-...  30
# 42  https://thuvienphapluat.vn/phap-luat/trach-nhi...  42

# %%
df = df[df['question'].str.endswith('?')]
df.head(10)
# Out:
#                                              question  \
# 0   Chi nhánh ngân hàng nước ngoài được quyết định...
# 1   Đối với chi nhánh ngân hàng nước ngoài, việc x...
# 2   Hồ sơ xuất toán nợ ra khỏi ngoại bảng đối với ...
# 3   Trách nhiệm của cơ quan hải quan trong kiểm tr...
# 4   Định mức thực tế sản xuất hàng hóa gia công...
# 5   Khi doanh nghiệp tính định mức thực tế của sản...
# 7            Bảo hiểm y tế được quy định như thế nào?
# 9   Trong thời gian nghỉ ốm đau công ty không đóng...
# 10  Doanh nghiệp kinh doanh casino có buộc phải xâ...
# 11  Quy chế giải quyết tranh chấp để xử lý tranh c...
#
#                                                answer  \
# 0   Căn cứ theo khoản 1 Điều 17 Thông tư 11/2021/T...
# 1   Căn cứ theo khoản 5 Điều 17 Thông tư 11/2021/T...
# 2   Căn cứ theo khoản 6 Điều 17 Thông tư 11/2021/T...
# 3   Theo quy định tại Điều 59 Luật Hải quan 2014 q...
# 4   Tại khoản 35 Điều 1 Thông tư 39/2018/TT-BTC sử...
# 5   Căn cứ tiểu mục 3 Mục 31 Bảng giải đáp thắc mắ...
# 7   Căn cứ khoản 1 Điều 2 Luật Bảo hiểm y tế 2008 ...
# 9   Căn cứ theo quy định tại khoản 5 Điều 42 Quyết...
# 10  Căn cứ khoản 1 Điều 22 Nghị định 03/2017/NĐ-CP...
# 11  Căn cứ khoản 1 Điều 22 Nghị định 03/2017/NĐ-CP...
#
#                                            references  \
# 0   ['https://thuvienphapluat.vn/van-ban/Tien-te-N...
# 1   ['https://thuvienphapluat.vn/van-ban/Tien-te-N...
# 2   ['https://thuvienphapluat.vn/van-ban/Tien-te-N...
# 3   ['https://thuvienphapluat.vn/van-ban/Thuong-ma...
# 4   ['https://thuvienphapluat.vn/van-ban/Xuat-nhap...
# 5   ['https://thuvienphapluat.vn/cong-van/Xuat-nha...
# 7   ['https://thuvienphapluat.vn/van-ban/Bao-hiem/...
# 9   ['https://thuvienphapluat.vn/van-ban/Bao-hiem/...
# 10  ['https://thuvienphapluat.vn/van-ban/Thuong-ma...
# 11  ['https://thuvienphapluat.vn/van-ban/Thuong-ma...
#
#                                          request_link  id
# 0   https://thuvienphapluat.vn/phap-luat/doi-voi-c...   0
# 1   https://thuvienphapluat.vn/phap-luat/doi-voi-c...   1
# 2   https://thuvienphapluat.vn/phap-luat/doi-voi-c...   2
# 3   https://thuvienphapluat.vn/phap-luat/ho-tro-ph...   3
# 4   https://thuvienphapluat.vn/phap-luat/ho-tro-ph...   4
# 5   https://thuvienphapluat.vn/phap-luat/ho-tro-ph...   5
# 7   https://thuvienphapluat.vn/phap-luat/trong-tho...   7
# 9   https://thuvienphapluat.vn/phap-luat/trong-tho...   9
# 10  https://thuvienphapluat.vn/phap-luat/doanh-ngh...  10
# 11  https://thuvienphapluat.vn/phap-luat/doanh-ngh...  11

# %%
df_with_anchor = df[df['references'].str.contains('anchor')]
df_no_anchor = df[~df['references'].str.contains('anchor')]
df_no_anchor.head(10)
# Out:
#                                               question  \
# 5    Khi doanh nghiệp tính định mức thực tế của sản...
# 19   Tạm dừng xét nghiệm virus SARS-CoV-2 cho người...
# 20   Yêu cầu tăng cường giám sát phòng, chống dịch ...
# 21   Hướng dẫn mới nhất về công tác phòng, chống dị...
# 117  Nguyên tắc khi xác định giá đất trên địa bàn t...
# 118  Tiêu chí xác định vị trí đất phi nông nghiệp t...
# 119  Quy định về giá đất ở trên địa bàn tỉnh Thái N...
# 221  Bảng lương cải cách tiền lương 2024 thay thế h...
# 222  Nguyên tắc xây dựng bảng lương mới đối với cán...
# 223  5 khoản phụ cấp nào bị cắt giảm khi thực hiện ...
#
#                                                 answer  \
# 5    Căn cứ tiểu mục 3 Mục 31 Bảng giải đáp thắc mắ...
# 19   Căn cứ Công điện 416/CĐ-TTg năm 2022, Bộ Y tế ...
# 20   Căn cứ tiểu mục 3 Mục IV Chương trình ban hành...
# 21   Theo Công văn 2860/BYT-DP năm 2022 tiếp tục th...
# 117  Giá đất được xác định theo mục đích sử dụng hợ...
# 118  Căn cứ vào điều kiện kết cấu hạ tầng kỹ thuật,...
# 119  - Giá đất ở tại đô thị, đất ở tại nông thôn bá...
# 221  Ngày 05/01/2024, Chính phủ ban hành Nghị quyết...
# 222  Tại Nghị quyết 27-NQ/TW năm 2018 đã nêu ra ngu...
# 223  Căn cứ theo Nghị quyết 27-NQ/TW năm 2018 có nộ...
#
#                                             references  \
# 5    ['https://thuvienphapluat.vn/cong-van/Xuat-nha...
# 19   ['https://thuvienphapluat.vn/van-ban/The-thao-...
# 20   ['https://thuvienphapluat.vn/van-ban/The-thao-...
# 21   ['https://thuvienphapluat.vn/cong-van/The-thao...
# 117  ['https://thuvienphapluat.vn/phap-luat/bang-gi...
# 118  ['https://thuvienphapluat.vn/phap-luat/bang-gi...
# 119  ['https://thuvienphapluat.vn/phap-luat/bang-gi...
# 221  ['https://thuvienphapluat.vn/van-ban/Thuong-ma...
# 222  ['https://thuvienphapluat.vn/van-ban/Lao-dong-...
# 223  ['https://thuvienphapluat.vn/van-ban/Lao-dong-...
#
#                                           request_link   id
# 5    https://thuvienphapluat.vn/phap-luat/ho-tro-ph...    5
# 19   https://thuvienphapluat.vn/phap-luat/ho-tro-ph...   19
# 20   https://thuvienphapluat.vn/phap-luat/ho-tro-ph...   20
# 21   https://thuvienphapluat.vn/phap-luat/ho-tro-ph...   21
# 117  https://thuvienphapluat.vn/phap-luat/ho-tro-ph...  117
# 118  https://thuvienphapluat.vn/phap-luat/ho-tro-ph...  118
# 119  https://thuvienphapluat.vn/phap-luat/ho-tro-ph...  119
# 221  https://thuvienphapluat.vn/phap-luat/ho-tro-ph...  221
# 222  https://thuvienphapluat.vn/phap-luat/ho-tro-ph...  222
# 223  https://thuvienphapluat.vn/phap-luat/ho-tro-ph...  223

# %%
# # Chuyển DataFrame thành JSON string
# json_data = df_with_anchor.to_json(orient='records', force_ascii=False, indent=4)
# # Thay thế ký tự \\/ bằng /
# json_data = json_data.replace('\/', '/')
# # Lưu JSON string vào file
# cleaned_file_path = '/Users/nhotin/Documents/GitHub/LegalBizAI_project/data/finetune/processed/finetuneda.json'
# with open(cleaned_file_path, 'w', encoding='utf-8') as f:
#     f.write(json_data)
